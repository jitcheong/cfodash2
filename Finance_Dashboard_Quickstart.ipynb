# %%
{
 "cells": [
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "## Finance Dashboard Quickstart\n",
    "This notebook demonstrates ingestion and query of financial data."
   ]
  },
  {
   "cell_type": "code",
   "metadata": {},
   "source": [
    "import pandas as pd\n",
    "from app import ingest_excel, store_financials, generate_cfo_commentary, validate_commentary, store_commentary, query_commentary"
   ]
  },
  {
   "cell_type": "code",
   "metadata": {},
   "source": [
    "# create sample Excel file\n",
    "sample = pd.DataFrame({\n",
    "    'Metric': ['Revenue', 'GM%', 'EBITDA%'],\n",
    "    'Unit': ['USD','%','%'],\n",
    "    'm': [100, 45, 15],\n",
    "    'vs BUD (ITM)': [10, -0.6, 0.4],\n",
    "    'vs n-1 (ITM)': [5, 0.7, -0.2]\n",
    "})\n",
    "path='Japan_Sep2023_ITM_YTD_v5.xlsx'\n",
    "sample.to_excel(path, index=False)"
   ]
  },
  {
   "cell_type": "code",
   "metadata": {},
   "source": [
    "df=ingest_excel(path)\n",
    "store_financials(df)\n",
    "print(generate_cfo_commentary(df))"
   ]
  },
  {
   "cell_type": "code",
   "metadata": {},
   "source": [
    "score, passed = validate_commentary('Revenue above budget due to strong demand', 'Revenue')\n",
    "store_commentary('Japan','2023-09-01','Revenue','Revenue above budget due to strong demand','Analyst',score,passed)\n",
    "query_commentary('Japan Revenue 2023')"
   ]
  }
 ],
 "metadata": {
  "kernelspec": {
   "display_name": "Python 3",
   "language": "python",
   "name": "python3"
  },
  "language_info": {
   "name": "python"
  }
 },
 "nbformat": 4,
 "nbformat_minor": 5
}
# Out:
# {'cells': [{'cell_type': 'markdown',
#    'metadata': {},
#    'source': ['## Finance Dashboard Quickstart\n',
#     'This notebook demonstrates ingestion and query of financial data.']},
#   {'cell_type': 'code',
#    'metadata': {},
#    'source': ['import pandas as pd\n',
#     'from app import ingest_excel, store_financials, generate_cfo_commentary, validate_commentary, store_commentary, query_commentary']},
#   {'cell_type': 'code',
#    'metadata': {},
#    'source': ['# create sample Excel file\n',
#     'sample = pd.DataFrame({\n',
#     "    'Metric': ['Revenue', 'GM%', 'EBITDA%'],\n",
#     "    'Unit': ['USD','%','%'],\n",
#     "    'm': [100, 45, 15],\n",
#     "    'vs BUD (ITM)': [10, -0.6, 0.4],\n",
#     "    'vs n-1 (ITM)': [5, 0.7, -0.2]\n",
#     '})\n',
#     "path='Japan_Sep2023_ITM_YTD_v5.xlsx'\n",
#     'sample.to_excel(path, index=False)']},
#   {'cell_type': 'code',
#    'metadata': {},
#    'source': ['df=ingest_excel(path)\n',
# ...
